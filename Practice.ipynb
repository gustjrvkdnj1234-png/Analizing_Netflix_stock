# %%
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/294.9 kB ? eta -:--:--
#    ---- ---------------------------------- 30.7/294.9 kB 435.7 kB/s eta 0:00:01
#    ----- --------------------------------- 41.0/294.9 kB 279.3 kB/s eta 0:00:01
#    ----- --------------------------------- 41.0/294.9 kB 279.3 kB/s eta 0:00:01
#    ------------ -------------------------- 92.2/294.9 kB 374.1 kB/s eta 0:00:01
#    -------------------------- ----------- 204.8/294.9 kB 731.4 kB/s eta 0:00:01
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import koreanize_matplotlib

# 1. 가상 데이터 생성 (CSV 파일 만들기)
data = {
    'title': ['Squid Game', 'The Glory', 'King the Land', 'Stranger Things', 'Bridgerton', 'The Crown', 'Moving', 'D.P.', 'Blue Giant', 'Signal'],
    'genre': ['Thriller', 'Drama', 'Romance', 'Sci-Fi', 'Romance', 'Drama', 'Sci-Fi', 'Drama', 'Animation', 'Thriller'],
    'view_count': [1500, 1200, 900, 1800, 1100, 850, 1300, 700, 500, 950], # 시청 횟수
    'rating': [4.8, 4.7, 3.9, 4.9, 4.2, 4.5, 4.6, 4.4, 4.8, 4.7],       # 평점
    'release_year': [2021, 2022, 2023, 2016, 2020, 2016, 2023, 2021, 2023, 2016]
}

df_origin = pd.DataFrame(data)
df_origin.to_csv('practice.csv', index = False)

# %%
df = pd.read_csv('practice.csv')
df.head()
# Out:
#              title     genre  view_count  rating  release_year
# 0       Squid Game  Thriller        1500     4.8          2021
# 1        The Glory     Drama        1200     4.7          2022
# 2    King the Land   Romance         900     3.9          2023
# 3  Stranger Things    Sci-Fi        1800     4.9          2016
# 4       Bridgerton   Romance        1100     4.2          2020

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         10 non-null     str
#  1   genre         10 non-null     str
#  2   view_count    10 non-null     int64
#  3   rating        10 non-null     float64
#  4   release_year  10 non-null     int64
# dtypes: float64(1), int64(2), str(2)
# memory usage: 532.0 bytes

# %%
genre_stats = df.groupby('genre')['rating'].mean().sort_values(ascending = False)

# %%
print(genre_stats)
# Out:
# genre
# Animation    4.800000
# Thriller     4.750000
# Sci-Fi       4.750000
# Drama        4.533333
# Romance      4.050000
# Name: rating, dtype: float64

# %%
plt.figure(figsize=(12,18))
